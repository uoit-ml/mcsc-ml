# %%
import tensorflow as tf
import numpy as np

# %%
raw_data = np.random.normal(10, 1, 100)

alpha = tf.constant(0.05)
curr_value = tf.placeholder(tf.float32)
prev_avg = tf.Variable(0.)

update_avg = alpha * curr_value + (1 - alpha) * prev_avg

# Need the following to send summary to tensorboard
avg_hist = tf.summary.scalar("running_average", update_avg)
value_hist = tf.summary.scalar("incoming_values", curr_value)
merged = tf.summary.merge_all()
writer = tf.summary.FileWriter("./logs")

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for i in range(len(raw_data)):
        summary_str, curr_avg = sess.run([merged, update_avg], feed_dict={curr_value: raw_data[i]})
        sess.run(tf.assign(prev_avg, curr_avg))
        print(raw_data[i], curr_avg)
        writer.add_summary(summary_str, i)
# Out:
# (12.047717723957348, 0.60238594)
# (9.9847113205179046, 1.0715022)
# (10.36452320081181, 1.5361532)
# (11.084017985525595, 2.0135465)
# (10.445637498696506, 2.4351511)
# (9.3905999390772177, 2.7829237)
# (9.5970400324629423, 3.1236293)
# (9.6597703766837242, 3.4504364)
# (10.449385187213943, 3.8003838)
# (10.698814737072031, 4.1453056)
# (9.2499098498050607, 4.4005356)
# (8.3099111962219041, 4.596004)
# (9.8376101133508644, 4.8580842)
# (10.519848488821252, 5.1411724)
# (10.540190987523713, 5.4111233)
# (10.508255740965462, 5.6659794)
# (9.4734368075343625, 5.8563523)
# (8.6646735356948064, 5.9967685)
# (10.520709596944837, 6.2229652)
# (11.697494619272844, 6.4966917)
# (10.060902308668604, 6.674902)
# (9.6899545405952541, 6.8256545)
# (9.4836141090488315, 6.9585524)
# (9.7387674411883474, 7.0975633)
# (8.781319805207918, 7.1817508)
# (9.380190300544065, 7.2916727)
# (9.3478438886393675, 7.3944817)
# (8.8412766256622231, 7.4668212)
# (9.53821096572673, 7.5703907)
# (11.046723641284057, 7.7442074)
# (10.6434044202144, 7.8891673)
# (11.597762171445634, 8.0745974)
# (10.209629768554215, 8.1813488)
# (10.79885948337858, 8.3122244)
# (12.555704403983199, 8.5243988)
# (7.6708082881421049, 8.481719)
# (10.413105829427868, 8.578289)
# (9.455230417300772, 8.6221352)
# (8.3958381441592724, 8.6108208)
# (10.59040852656161, 8.7097998)
# (9.0483251442055952, 8.7267265)
# (10.586282629683865, 8.8197041)
# (9.9801079093014575, 8.8777237)
# (9.2887677808086728, 8.8982754)
# (10.35156795362921, 8.9709396)
# (10.093535147236187, 9.0270691)
# (10.093088144187993, 9.0803699)
# (10.241819845938405, 9.138442)
# (7.6432778469705367, 9.0636835)
# (9.234396324426223, 9.0722189)
# (11.728328499478499, 9.2050238)
# (9.5745404075392084, 9.2235003)
# (10.547003076686867, 9.2896757)
# (8.5959806377450789, 9.2549906)
# (7.1466634075983322, 9.1495743)
# (9.4280868039032235, 9.1634998)
# (10.123826938385411, 9.2115164)
# (9.3263799523710542, 9.2172594)
# (9.1901362221333667, 9.2159033)
# (10.296113785421293, 9.2699137)
# (9.8216290224054994, 9.2974987)
# (10.119917051847159, 9.3386192)
# (10.286796888366565, 9.3860273)
# (9.5338367379324147, 9.3934183)
# (10.780238898923134, 9.462759)
# (10.388093965727563, 9.5090256)
# (11.385462012734683, 9.6028471)
# (9.8083834563382446, 9.6131239)
# (10.656082989540568, 9.6652718)
# (11.826448924170736, 9.7733307)
# (9.8360194521518345, 9.7764654)
# (8.8894851650244266, 9.7321167)
# (9.1148827269587827, 9.7012548)
# (10.81089377697443, 9.7567368)
# (9.4328200435450107, 9.7405405)
# (9.9423486679941302, 9.7506304)
# (8.305460684384169, 9.6783714)
# (9.6937375041749316, 9.6791391)
# (11.762462338154304, 9.7833052)
# (10.743580172157149, 9.8313189)
# (11.338305866812783, 9.9066687)
# (9.4100493759054125, 9.8818378)
# (11.536834499507505, 9.9645872)
# (10.36681481831895, 9.9846992)
# (9.8128086605022773, 9.9761047)
# (10.17500217703893, 9.9860497)
# (11.015501096556676, 10.037521)
# (10.902345859280688, 10.080763)
# (10.234985966716106, 10.088474)
# (10.422720791300828, 10.105186)
# (10.045436591713726, 10.102199)
# (9.7427447927537347, 10.084226)
# (11.185338701736995, 10.139281)
# (9.4046509739663531, 10.102551)
# (11.021779438759856, 10.148512)
# (10.923948085245437, 10.187284)
# (9.5902932035093471, 10.157435)
# (10.623336100968949, 10.180731)
# (9.7954334965558321, 10.161466)
# (8.6367862460227265, 10.085231)
